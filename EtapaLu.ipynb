# %% [markdown]
# ***Aplicar os conceitos de estatística trabalhados durante toda a unidade curricular no arquivo orientado pelo instrutor***

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_excel('BaseDPEvolucaoMensalCisp.xlsx')

# %%
display(dados.head())
display(dados.describe())
dadoscopia=dados.copy()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
# 2                 1                0                          0
# 3                 1                0                          0
# 4                 3                0                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
# 2                      0                   637     3
# 3                      0                   473     3
# 4                      0                   147     3
#
# [5 rows x 63 columns]
#                cisp           mes           ano          aisp          risp  \
# count  35122.000000  35122.000000  35122.000000  35122.000000  35122.000000
# mean      81.722083      6.449917   2013.521781     20.107055      3.870024
# std       48.318773      3.436425      6.248810     11.337913      2.011751
# min        1.000000      1.000000   2003.000000      1.000000      1.000000
# 25%       38.000000      3.000000   2008.000000     10.000000      2.000000
# 50%       78.000000      6.000000   2014.000000     20.000000      4.000000
# 75%      125.000000      9.000000   2019.000000     30.000000      6.000000
# max      168.000000     12.000000   2024.000000     43.000000      7.000000
#
#               mcirc    hom_doloso  lesao_corp_morte    latrocinio  \
# count  3.512200e+04  35122.000000      35122.000000  35122.000000
# mean   3.794961e+06      2.997922          0.027219      0.097830
# std    1.746085e+06      4.404031          0.176974      0.371221
# min    3.300100e+06      0.000000          0.000000      0.000000
# 25%    3.302601e+06      0.000000          0.000000      0.000000
# 50%    3.304557e+06      1.000000          0.000000      0.000000
# 75%    3.304557e+06      4.000000          0.000000      0.000000
# max    9.999999e+06     43.000000          6.000000      9.000000
#
#                cvli  ...           cmp          cmba        ameaca  \
# count  35122.000000  ...  30476.000000  30476.000000  35122.000000
# mean       3.122971  ...      8.862876      0.626296     41.200928
# std        4.520554  ...     15.219197      1.646543     39.458048
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%        0.000000  ...      2.000000      0.000000     14.000000
# 50%        1.000000  ...      5.000000      0.000000     30.000000
# 75%        4.000000  ...     11.000000      1.000000     56.000000
# max       43.000000  ...    419.000000     60.000000    370.000000
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# count           35122.000000      35122.000000     35122.000000
# mean                3.183674          0.365327         0.023006
# std                 4.128044          1.006563         0.181378
# min                 0.000000          0.000000         0.000000
# 25%                 0.000000          0.000000         0.000000
# 50%                 2.000000          0.000000         0.000000
# 75%                 5.000000          0.000000         0.000000
# max               191.000000        112.000000        10.000000
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# count               35122.000000           35122.000000          35122.000000
# mean                    0.013866               0.002192            435.277262
# std                     0.133320               0.048564            389.486583
# min                     0.000000               0.000000              0.000000
# 25%                     0.000000               0.000000            104.000000
# 50%                     0.000000               0.000000            365.000000
# 75%                     0.000000               0.000000            652.000000
# max                     4.000000               2.000000           3185.000000
#
#                fase
# count  35122.000000
# mean       2.988298
# std        0.107543
# min        2.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
#
# [8 rows x 60 columns]

# %%
crimes = ['hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli', 'hom_por_interv_policial', 'letalidade_violenta', 'tentat_hom', 'lesao_corp_dolosa', 'estupro', 'hom_culposo', 'lesao_corp_culposa', 
          'roubo_transeunte', 'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo', 'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco', 'roubo_cx_eletronico', 
          'roubo_conducao_saque', 'roubo_apos_saque', 'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos', 'furto_transeunte', 'furto_coletivo', 'furto_celular', 'furto_bicicleta', 
          'outros_furtos', 'total_furtos', 'sequestro', 'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas', 'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor', 'recuperacao_veiculos', 
          'apf', 'aaapai', 'cmp', 'cmba', 'ameaca', 'pessoas_desaparecidas', 'encontro_cadaver',
          'encontro_ossada', 'pol_militares_mortos_serv', 'pol_civis_mortos_serv'
]

# %%
# Calcular o coeficiente de variação e a distância da variância em relação à média para as variáveis de interesse
resultados = []

for crime in crimes:
    if crime in dados.columns:
        media = dados[crime].mean()
        variancia = dados[crime].var()
        desvio_padrao = dados[crime].std()
        
        # Coeficiente de variação (em %)
        coeficiente_variacao = (desvio_padrao / media) * 100 if media != 0 else None
        
        # Distância da variância em relação à média
        distancia_variancia_media = variancia - media
        
        resultados.append({
            'Crime': crime,
            'Média': media,
            'Variância': variancia,
            'Desvio Padrão': desvio_padrao,
            'Coeficiente de Variação (%)': coeficiente_variacao,
            'Distância da Variância em relação à Média': distancia_variancia_media
        })

# Converter para DataFrame para visualização
resultados_df = pd.DataFrame(resultados)

# Exibir resultados
display(resultados_df)
# Out:
#                          Crime      Média     Variância  Desvio Padrão  \
# 0                   hom_doloso   2.997922     19.395486       4.404031
# 1             lesao_corp_morte   0.027219      0.031320       0.176974
# 2                   latrocinio   0.097830      0.137805       0.371221
# 3                         cvli   3.122971     20.435406       4.520554
# 4      hom_por_interv_policial   0.627897      2.479997       1.574801
# 5          letalidade_violenta   3.750868     28.417018       5.330762
# 6                   tentat_hom   2.861084     15.972701       3.996586
# 7            lesao_corp_dolosa  44.706366   1800.769476      42.435474
# 8                      estupro   2.883520     13.140927       3.625042
# 9                  hom_culposo   1.394539      3.618629       1.902269
# 10          lesao_corp_culposa  21.654405    509.698504      22.576503
# 11            roubo_transeunte  34.811799   2588.883061      50.881068
# 12               roubo_celular   8.011076    185.364047      13.614847
# 13           roubo_em_coletivo   5.645350    122.284573      11.058236
# 14                   roubo_rua  48.468225   4835.989039      69.541276
# 15               roubo_veiculo  19.254769   1099.618073      33.160490
# 16                 roubo_carga   3.145550     53.248881       7.297183
# 17              roubo_comercio   3.171858     17.216841       4.149318
# 18            roubo_residencia   0.831957      1.706108       1.306181
# 19                 roubo_banco   0.015574      0.016870       0.129883
# 20         roubo_cx_eletronico   0.029086      0.033027       0.181733
# 21        roubo_conducao_saque   0.073287      0.104933       0.323934
# 22            roubo_apos_saque   0.914185      3.572887       1.890208
# 23             roubo_bicicleta   0.102972      0.248589       0.498587
# 24               outros_roubos  10.423524    283.261555      16.830376
# 25                total_roubos  86.379990  14584.701479     120.767137
# 26              furto_veiculos  11.037270    192.513317      13.874917
# 27            furto_transeunte  13.970759    924.752967      30.409751
# 28              furto_coletivo   4.654148     63.401097       7.962481
# 29               furto_celular  11.757730    472.021968      21.726067
# 30             furto_bicicleta   1.273614      9.664360       3.108755
# 31               outros_furtos  54.157053   2869.310603      53.565946
# 32                total_furtos  96.220005  11458.567724     107.044700
# 33                   sequestro   0.003872      0.004768       0.069054
# 34                    extorsao   1.082626      3.223662       1.795456
# 35         sequestro_relampago   0.063635      0.125702       0.354545
# 36                 estelionato  26.624053   1896.360126      43.547217
# 37            apreensao_drogas  11.333722    217.931421      14.762501
# 38                posse_drogas   4.937229    103.246757      10.161041
# 39              trafico_drogas   5.795150     59.458839       7.710956
# 40  apreensao_drogas_sem_autor   1.342729      6.924272       2.631401
# 41        recuperacao_veiculos  14.092705    607.573194      24.649000
# 42                         apf  18.361891    327.305388      18.091583
# 43                      aaapai   3.807718     32.281714       5.681700
# 44                         cmp   8.862876    231.623953      15.219197
# 45                        cmba   0.626296      2.711104       1.646543
# 46                      ameaca  41.200928   1556.937532      39.458048
# 47       pessoas_desaparecidas   3.183674     17.040748       4.128044
# 48            encontro_cadaver   0.365327      1.013169       1.006563
# 49             encontro_ossada   0.023006      0.032898       0.181378
# 50   pol_militares_mortos_serv   0.013866      0.017774       0.133320
# 51       pol_civis_mortos_serv   0.002192      0.002358       0.048564
#
#     Coeficiente de Variação (%)  Distância da Variância em relação à Média
# 0                    146.902798                                  16.397564
# 1                    650.174539                                   0.004100
# 2                    379.453714                                   0.039975
# 3                    144.751686                                  17.312434
# 4                    250.805565                                   1.852100
# 5                    142.120729                                  24.666150
# 6                    139.687819                                  13.111617
# 7                     94.920428                                1756.063109
# 8                    125.715834                                  10.257406
# 9                    136.408477                                   2.224090
# 10                   104.258250                                 488.044099
# 11                   146.160410                                2554.071262
# 12                   169.950293                                 177.352971
# 13                   195.882178                                 116.639222
# 14                   143.478074                                4787.520814
# 15                   172.219617                                1080.363303
# 16                   231.984345                                  50.103331
# 17                   130.816638                                  14.044983
# 18                   157.000942                                   0.874151
# 19                   833.960807                                   0.001295
# 20                   624.814514                                   0.003941
# 21                   442.004931                                   0.031646
# 22                   206.764324                                   2.658702
# 23                   484.196963                                   0.145617
# 24                   161.465320                                 272.838032
# 25                   139.809159                               14498.321490
# 26                   125.709679                                 181.476047
# 27                   217.667136                                 910.782208
# 28                   171.083514                                  58.746949
# 29                   184.781129                                 460.264237
# 30                   244.089254                                   8.390745
# 31                    98.908533                                2815.153551
# 32                   111.249942                               11362.347719
# 33                  1783.322070                                   0.000896
# 34                   165.842623                                   2.141035
# 35                   557.150550                                   0.062067
# 36                   163.563439                                1869.736073
# 37                   130.252885                                 206.597699
# 38                   205.804522                                  98.309528
# 39                   133.058772                                  53.663689
# 40                   195.974153                                   5.581544
# 41                   174.906089                                 593.480489
# 42                    98.527886                                 308.943497
# 43                   149.215372                                  28.473996
# 44                   171.718496                                 222.761077
# 45                   262.901679                                   2.084808
# 46                    95.769803                                1515.736603
# 47                   129.662901                                  13.857074
# 48                   275.524102                                   0.647842
# 49                   788.411211                                   0.009893
# 50                   961.490883                                   0.003908
# 51                  2215.144303                                   0.000166
